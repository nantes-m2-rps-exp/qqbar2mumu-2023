# %%
import uproot
import awkward as ak
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
import hist
import vector
import os
import subprocess
import gc
import pandas as pd
from scipy.optimize import curve_fit
print("uproot version", uproot.__version__)
print("awkward version", ak.__version__)
print("numpy version", np.__version__)
print("matplotlib version", matplotlib.__version__)
print("hist version", hist.__version__)
print("vector version", vector.__version__)
#print("os version", os.__version__)
#print("subprocess version", subprocess.__version__)
#print("gc version", gc.__version__)
print("pandas version", pd.__version__)
#print("scipy.optimize version", scipy.optimize.__version__)
# Out:
# uproot version 5.0.12
# awkward version 2.4.3
# numpy version 1.25.2
# matplotlib version 3.8.0
# hist version 2.7.2
# vector version 1.1.1
# pandas version 1.5.3

# %%
vector.register_awkward()

# %%
# Fonction de récupération de certains vecteurs et "triggers" des événements.
def getTracksData(events):
    return ak.zip({
        "px"      : events["Muon_Px"],
        "py"      : events["Muon_Py"],
        "pz"      : events["Muon_Pz"],
        "E"       : events["Muon_E"],
        "charge"  : events["Muon_Charge"],
        "thetaAbs": events["Muon_thetaAbs"],
        "matched" : events["Muon_matchedTrgThreshold"]},
        with_name='Momentum4D')

# Fonction de sommation des composantes quadri-vectorielles des paires de di-muons candidats.
def Momentum4D(events):
    return ak.zip({
        "px": events["0"].px + events["1"].px,
        "py": events["0"].py + events["1"].py,
        "pz": events["0"].pz + events["1"].pz,
        "E" : events["0"].E  + events["1"].E},
        with_name="Momentum4D")

# Fonction principale d'extraction des données expérimentales.
def scan(dataDescription, 
         hMagData:hist.Hist, hPhiData:hist.Hist, hEtaData:hist.Hist, hYData:hist.Hist, hPtData:hist.Hist, hMassData:hist.Hist, hMass_OSData:hist.Hist, hMass_LSData:hist.Hist,
         eventSelectorData = lambda x:[True]*len(x),
         trackSelectorData = lambda x:[True]*len(x),
         pairSelectorData = lambda x:[True]*len(x),
         verbose:bool = False):
    """ Loop over data to fill the invariant mass histogram.
        
        :param: dataDescription: is anything uproot.iterate can take.
                typical something like run*.data.root:eventsTree in our case
        :param: eventSelector: returns an array of bool from an array of events
        :param: trackSelector: returns an array of bool from an array of tracks
    """
    # Initialisation de plusieurs compteurs pour observer le nombre d'événements "nGoodEntries", de traces "nGoodTracks" et de paires "nGoodOS-LS" conservés par "run" de données.
    nEntries = nGoodEvents = nGoodTracks = nGoodEntries = nPairs = nOS = nGoodOS = nLS = nGoodLS = 0
    
    # Boucle d'itération sur le nombre d'événements. Chaque batch contient le nombre d'événement ainsi que ses caractéristiques.
    for batch in uproot.iterate(dataDescription,
                                ["isCINT", "isCMUL", "isCMSL", "Muon_Px", "Muon_Py", "Muon_Pz", "Muon_E", "Muon_Charge", "Muon_thetaAbs", "Muon_matchedTrgThreshold"],                                
                                report = True):
        
        # Récupération et test sur les événéements pour éviter les données corrompues.
        events = batch[0] # batch[1] is the report info
        if len(events) < 1000:
            print("something is wrong",batch[1]) # this is a protection for some corrupted input data files 
            break
        
        # Selections sur les événements et les traces.
        goodEvents = events[eventSelectorData(events)]
        tracks = getTracksData(goodEvents)
        goodTracks = tracks[trackSelectorData(tracks)]
        
        # Formation de toutes les combinaisons de paires possibles par événements.
        pairs = ak.combinations(goodTracks, 2)
        
        # Condition et selection sur les paires de muons candidats de signe opposé (OS: Opposite-Sign) 
        condition_OS = np.logical_or(np.logical_and(pairs["0"].charge ==  1, pairs["1"].charge == -1),
                                     np.logical_and(pairs["0"].charge == -1, pairs["1"].charge ==  1))
        pairs_OS = pairs[condition_OS]
        OS = Momentum4D(pairs_OS)
        goodOS = OS[pairSelectorData(OS)]
        
        # Condition et selection sur les paires de muons candidats de même signe (LS: Like-Sign)
        condition_LS = np.logical_or(np.logical_and(pairs["0"].charge == -1, pairs["1"].charge == -1),
                                     np.logical_and(pairs["0"].charge ==  1, pairs["1"].charge ==  1))
        pairs_LS = pairs[condition_LS]
        LS = Momentum4D(pairs_LS)
        goodLS = LS[pairSelectorData(LS)]
        
        
        # Remplissage des histogrammes
        hMagData.fill(ak.flatten(goodTracks.p))  
        hPtData.fill(ak.flatten(goodTracks.pt))
        hPhiData.fill(ak.flatten(goodTracks.phi))
        hEtaData.fill(ak.flatten(goodTracks.eta))
        hMassData.fill(ak.flatten(goodTracks.mass))
        hYData.fill(ak.flatten(goodOS.rapidity))
        hMass_OSData.fill(ak.flatten(goodOS.mass))
        hMass_LSData.fill(ak.flatten(goodLS.mass))
        

        # Actualisation des compteurs par "batch" de données.
        nEntries += len(events)
        nGoodEvents += len(goodEvents)
        nGoodTracks += len(ak.flatten(goodTracks))
        nGoodEntries += list(ak.num(goodTracks) > 0).count(True)
        nPairs += len(ak.flatten(pairs))
        nOS += len(ak.flatten(OS))
        nGoodOS += len(ak.flatten(goodOS))
        nLS += len(ak.flatten(LS))
        nGoodLS += len(ak.flatten(goodLS))

        # Affichage du "run" extrait et des compteurs associés.
        if verbose:
            print(batch[1])
            print("Entries: ", nEntries)
            print("Good Events: ", nGoodEvents)
            print("Good Tracks: ", nGoodTracks)
            print("Good Entries: ", nGoodEntries)
            print("Pairs: ", nPairs)
            print("OS: ", nOS)
            print("Good OS:", nGoodOS)
            print("LS: ", nLS)
            print("Good LS:", nGoodLS)
            print("---------------------------------------------------------------------------------------")
        gc.collect()
        
    # Renvoie les compteurs pour un affichage final.
    return nEntries, nGoodEvents, nGoodTracks, nGoodEntries, nPairs, nOS, nGoodOS, nLS, nGoodLS

# %%
# Numéros des "runs" gardés en commun avec tous les groupes de recherches.
SAMPLE_RUNS = sorted([290323, 290327, 290848, 291361, 291360, 291362, 290853, 290860, 291373, 290374, 290375, 291399,
               291400, 290894, 290895, 290404, 291943, 291944, 291948, 291953, 290932, 290423, 291447, 290935, 
               290425, 290427, 291451, 291453, 291976, 291982, 290456, 290458, 290459, 291482, 291485, 290975, 
               290980, 290469, 292012, 291002, 291003, 291004, 291005, 290501, 292040, 292060, 292061, 292062, 
               291041, 290539, 290540, 292075, 292077, 292080, 290549, 290553, 291590, 292106, 292108, 292109, 
               292115, 290590, 291618, 291622, 291624, 292140, 290612, 292160, 292162, 292163, 292164, 292166, 
               290632, 291657, 292168, 292192, 290658, 290660, 291690, 291692, 291694, 291698, 291706, 290687, 
               290692, 290696, 290699, 292242, 292265, 291755, 292269, 292270, 291760, 292273, 292274, 290742, 
               291769, 291263, 290764, 290766, 291283, 291284, 291285, 291795, 291796, 290776, 291803, 290787])
print(len(SAMPLE_RUNS))
# Out:
# 108

# %%
# %%time

# Création des différents histogrammes pour visualiser les résultats issus des données expérimentales.
hMag= hist.Hist(hist.axis.Regular(bins = 100, start = 0, stop = 100, name = '$|p|$'))
hPhi = hist.Hist(hist.axis.Regular(bins = 200, start = -np.pi, stop = np.pi, name = '$\phi$'))
hEta = hist.Hist(hist.axis.Regular(bins = 100, start = -6, stop = 0, name = '$\eta$'))
hPt = hist.Hist(hist.axis.Regular(bins = 100, start = 0, stop = 100, name = '$p_T$'))
hMass = hist.Hist(hist.axis.Regular(bins = 100, start = 0, stop = 0.2, name = '$m_{\mu}$'))

hY_OS = hist.Hist(hist.axis.Regular(bins = 100, start = -6, stop = 0, name = '$y$'))
hMass_OS = hist.Hist(hist.axis.Regular(bins = 100, start = 1.5, stop = 5, name = '$m_{\mu \mu}$'))
hMass_LS = hist.Hist(hist.axis.Regular(bins = 100, start = 1.5, stop = 5, name = '$m_{\mu \mu}$'))

# Initialisation des compteurs pour avoir un rendu final sur tous les "runs".
Entries = goodEvents = goodTracks = goodEntries = Pairs = goodPairs = OS = goodOS = LS = goodLS = 0

# Appel de la fonction "scan" pour l'extraction des données pour tous les "runs".
for run in SAMPLE_RUNS:
    a, b, c, d, e, f, g, h, i = scan(dataDescription = f"/pbs/throng/training/nantes-m2-rps-exp/data/run{run}.data.root:eventsTree",
                                      hMagData = hMag, hPhiData = hPhi, hEtaData = hEta, hYData = hY_OS, hPtData = hPt, hMassData = hMass, hMass_OSData = hMass_OS, hMass_LSData = hMass_LS,
                                      eventSelectorData = lambda x: x["isCMUL"] == True, 
                                      trackSelectorData = lambda x: (x.thetaAbs < 10) & (x.thetaAbs > 2) & (x.pt > 0.5) & (x.eta > -4.0) & (x.eta < -2.5),# & (x.matched == 2),
                                      pairSelectorData = lambda x: (x.rapidity > -2.8) & (x.rapidity < -2.5),# & (x.pt > 6) & (x.pt < 8),
                                      verbose = True)
    
    # Actualisation des compteurs.
    Entries += a
    goodEvents += b
    goodTracks += c
    goodEntries += d
    Pairs += e
    OS += f
    goodOS += g
    LS += h
    goodLS += i

# Affichage final sur le comptage total des événements, traces et paires gardés.
print("Entries: ", Entries)
print("Good Events: ", goodEvents)
print("Good Tracks: ", goodTracks)
print("Good Entries: ", goodEntries)
print("Pairs: ", Pairs)
print("OS: ", OS)
print("Good OS: ", goodOS)
print("LS: ", LS)
print("Good LS: ", goodLS)
# Out:
# <Report start=0 stop=2139140 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290323.data.root:/eventsTree;1'>
# Entries:  2139140
# Good Events:  410205
# Good Tracks:  288978
# Good Entries:  231741
# Pairs:  60444
# OS:  51629
# Good OS: 4040
# LS:  8815
# Good LS: 973
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=190395 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290327.data.root:/eventsTree;1'>
# Entries:  190395
# Good Events:  36880
# Good Tracks:  25729
# Good Entries:  20668
# Pairs:  5362
# OS:  4592
# Good OS: 363
# LS:  770
# Good LS: 89
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1109829 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290374.data.root:/eventsTree;1'>
# Entries:  1109829
# Good Events:  213125
# Good Tracks:  150005
# Good Entries:  120273
# Pairs:  31325
# OS:  26787
# Good OS: 2098
# LS:  4538
# Good LS: 540
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=446234 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290375.data.root:/eventsTree;1'>
# Entries:  446234
# Good Events:  85523
# Good Tracks:  60203
# Good Entries:  48226
# Pairs:  12589
# OS:  10841
# Good OS: 913
# LS:  1748
# Good LS: 197
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2580759 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290404.data.root:/eventsTree;1'>
# Entries:  2580759
# Good Events:  497375
# Good Tracks:  351370
# Good Entries:  281458
# Pairs:  73618
# OS:  63098
# Good OS: 4831
# LS:  10520
# Good LS: 1118
# ---------------------------------------------------------------------------------------
# <Report start=2580759 stop=2755185 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290404.data.root:/eventsTree;1'>
# Entries:  2755185
# Good Events:  530726
# Good Tracks:  374853
# Good Entries:  300276
# Pairs:  78538
# OS:  67297
# Good OS: 5168
# LS:  11241
# Good LS: 1191
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=966682 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290423.data.root:/eventsTree;1'>
# Entries:  966682
# Good Events:  188217
# Good Tracks:  132933
# Good Entries:  106667
# Pairs:  27701
# OS:  23680
# Good OS: 1832
# LS:  4021
# Good LS: 385
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2570054 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290425.data.root:/eventsTree;1'>
# Entries:  2570054
# Good Events:  501218
# Good Tracks:  354712
# Good Entries:  284511
# Pairs:  73762
# OS:  63641
# Good OS: 4747
# LS:  10121
# Good LS: 967
# ---------------------------------------------------------------------------------------
# <Report start=2570054 stop=2731811 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290425.data.root:/eventsTree;1'>
# Entries:  2731811
# Good Events:  532676
# Good Tracks:  376789
# Good Entries:  302249
# Pairs:  78308
# OS:  67556
# Good OS: 5038
# LS:  10752
# Good LS: 1030
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=893585 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290427.data.root:/eventsTree;1'>
# Entries:  893585
# Good Events:  174374
# Good Tracks:  123590
# Good Entries:  98865
# Pairs:  25979
# OS:  22373
# Good OS: 1723
# LS:  3606
# Good LS: 349
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=518307 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290456.data.root:/eventsTree;1'>
# Entries:  518307
# Good Events:  101348
# Good Tracks:  71878
# Good Entries:  57609
# Pairs:  15004
# OS:  12935
# Good OS: 1050
# LS:  2069
# Good LS: 202
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=427022 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290458.data.root:/eventsTree;1'>
# Entries:  427022
# Good Events:  83406
# Good Tracks:  58751
# Good Entries:  47170
# Pairs:  12206
# OS:  10523
# Good OS: 835
# LS:  1683
# Good LS: 173
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2570701 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290459.data.root:/eventsTree;1'>
# Entries:  2570701
# Good Events:  503184
# Good Tracks:  354938
# Good Entries:  284977
# Pairs:  73578
# OS:  63316
# Good OS: 4749
# LS:  10262
# Good LS: 990
# ---------------------------------------------------------------------------------------
# <Report start=2570701 stop=4856224 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290459.data.root:/eventsTree;1'>
# Entries:  4856224
# Good Events:  950513
# Good Tracks:  670659
# Good Entries:  538398
# Pairs:  139202
# OS:  119750
# Good OS: 9041
# LS:  19452
# Good LS: 1901
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2572968 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290469.data.root:/eventsTree;1'>
# Entries:  2572968
# Good Events:  501181
# Good Tracks:  355502
# Good Entries:  285277
# Pairs:  73861
# OS:  63686
# Good OS: 4840
# LS:  10175
# Good LS: 995
# ---------------------------------------------------------------------------------------
# <Report start=2572968 stop=2979620 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290469.data.root:/eventsTree;1'>
# Entries:  2979620
# Good Events:  580748
# Good Tracks:  411999
# Good Entries:  330625
# Pairs:  85609
# OS:  73804
# Good OS: 5562
# LS:  11805
# Good LS: 1155
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2787926 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290501.data.root:/eventsTree;1'>
# Entries:  2787926
# Good Events:  545310
# Good Tracks:  383865
# Good Entries:  307719
# Pairs:  80178
# OS:  68693
# Good OS: 5334
# LS:  11485
# Good LS: 1244
# ---------------------------------------------------------------------------------------
# <Report start=2787926 stop=3564254 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290501.data.root:/eventsTree;1'>
# Entries:  3564254
# Good Events:  697666
# Good Tracks:  491086
# Good Entries:  393858
# Pairs:  102384
# OS:  87669
# Good OS: 6816
# LS:  14715
# Good LS: 1579
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1473238 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290539.data.root:/eventsTree;1'>
# Entries:  1473238
# Good Events:  288395
# Good Tracks:  203776
# Good Entries:  163091
# Pairs:  42890
# OS:  36652
# Good OS: 2841
# LS:  6238
# Good LS: 695
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1296804 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290540.data.root:/eventsTree;1'>
# Entries:  1296804
# Good Events:  253680
# Good Tracks:  179720
# Good Entries:  143775
# Pairs:  37904
# OS:  32395
# Good OS: 2485
# LS:  5509
# Good LS: 575
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2167910 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290549.data.root:/eventsTree;1'>
# Entries:  2167910
# Good Events:  423714
# Good Tracks:  298948
# Good Entries:  240023
# Pairs:  62122
# OS:  53409
# Good OS: 4044
# LS:  8713
# Good LS: 938
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1708408 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290553.data.root:/eventsTree;1'>
# Entries:  1708408
# Good Events:  333281
# Good Tracks:  236867
# Good Entries:  189878
# Pairs:  49474
# OS:  42553
# Good OS: 3284
# LS:  6921
# Good LS: 641
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2556077 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290590.data.root:/eventsTree;1'>
# Entries:  2556077
# Good Events:  500555
# Good Tracks:  352829
# Good Entries:  282597
# Pairs:  74109
# OS:  63136
# Good OS: 5096
# LS:  10973
# Good LS: 1345
# ---------------------------------------------------------------------------------------
# <Report start=2556077 stop=2565429 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290590.data.root:/eventsTree;1'>
# Entries:  2565429
# Good Events:  502415
# Good Tracks:  354144
# Good Entries:  283654
# Pairs:  74377
# OS:  63374
# Good OS: 5116
# LS:  11003
# Good LS: 1350
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=686568 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290612.data.root:/eventsTree;1'>
# Entries:  686568
# Good Events:  134577
# Good Tracks:  95289
# Good Entries:  76392
# Pairs:  19974
# OS:  16924
# Good OS: 1362
# LS:  3050
# Good LS: 383
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=625363 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290632.data.root:/eventsTree;1'>
# Entries:  625363
# Good Events:  121975
# Good Tracks:  86509
# Good Entries:  69171
# Pairs:  18337
# OS:  15606
# Good OS: 1179
# LS:  2731
# Good LS: 317
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=208853 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290658.data.root:/eventsTree;1'>
# Entries:  208853
# Good Events:  40898
# Good Tracks:  28894
# Good Entries:  23291
# Pairs:  5890
# OS:  5035
# Good OS: 372
# LS:  855
# Good LS: 86
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2432119 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290660.data.root:/eventsTree;1'>
# Entries:  2432119
# Good Events:  476233
# Good Tracks:  336984
# Good Entries:  270109
# Pairs:  70561
# OS:  60432
# Good OS: 4553
# LS:  10129
# Good LS: 988
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2721026 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290687.data.root:/eventsTree;1'>
# Entries:  2721026
# Good Events:  530582
# Good Tracks:  374239
# Good Entries:  299625
# Pairs:  78880
# OS:  67349
# Good OS: 5466
# LS:  11531
# Good LS: 1385
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2569620 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290692.data.root:/eventsTree;1'>
# Entries:  2569620
# Good Events:  502345
# Good Tracks:  354536
# Good Entries:  284463
# Pairs:  73852
# OS:  63318
# Good OS: 4829
# LS:  10534
# Good LS: 1062
# ---------------------------------------------------------------------------------------
# <Report start=2569620 stop=3496470 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290692.data.root:/eventsTree;1'>
# Entries:  3496470
# Good Events:  683655
# Good Tracks:  483015
# Good Entries:  387161
# Pairs:  101025
# OS:  86652
# Good OS: 6561
# LS:  14373
# Good LS: 1459
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1391699 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290696.data.root:/eventsTree;1'>
# Entries:  1391699
# Good Events:  271426
# Good Tracks:  192189
# Good Entries:  154237
# Pairs:  40098
# OS:  34348
# Good OS: 2632
# LS:  5750
# Good LS: 599
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1194842 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290699.data.root:/eventsTree;1'>
# Entries:  1194842
# Good Events:  232843
# Good Tracks:  158927
# Good Entries:  128502
# Pairs:  32016
# OS:  27458
# Good OS: 2064
# LS:  4558
# Good LS: 411
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2338406 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290742.data.root:/eventsTree;4'>
# Entries:  2338406
# Good Events:  439687
# Good Tracks:  266909
# Good Entries:  219739
# Pairs:  49493
# OS:  42236
# Good OS: 3584
# LS:  7257
# Good LS: 842
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1018967 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290764.data.root:/eventsTree;1'>
# Entries:  1018967
# Good Events:  198881
# Good Tracks:  135601
# Good Entries:  109514
# Pairs:  27445
# OS:  23543
# Good OS: 1869
# LS:  3902
# Good LS: 456
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1042381 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290766.data.root:/eventsTree;1'>
# Entries:  1042381
# Good Events:  202993
# Good Tracks:  138626
# Good Entries:  111770
# Pairs:  28351
# OS:  24192
# Good OS: 1929
# LS:  4159
# Good LS: 432
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1266417 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290776.data.root:/eventsTree;1'>
# Entries:  1266417
# Good Events:  247008
# Good Tracks:  168520
# Good Entries:  136345
# Pairs:  33781
# OS:  29147
# Good OS: 2167
# LS:  4634
# Good LS: 394
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1145636 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290787.data.root:/eventsTree;1'>
# Entries:  1145636
# Good Events:  223432
# Good Tracks:  152597
# Good Entries:  123271
# Pairs:  30863
# OS:  26628
# Good OS: 1973
# LS:  4235
# Good LS: 370
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2609146 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290848.data.root:/eventsTree;1'>
# Entries:  2609146
# Good Events:  508821
# Good Tracks:  347289
# Good Entries:  280699
# Pairs:  70036
# OS:  60048
# Good OS: 4534
# LS:  9988
# Good LS: 1072
# ---------------------------------------------------------------------------------------
# <Report start=2609146 stop=2795713 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290848.data.root:/eventsTree;1'>
# Entries:  2795713
# Good Events:  545270
# Good Tracks:  372262
# Good Entries:  300782
# Pairs:  75214
# OS:  64469
# Good OS: 4901
# LS:  10745
# Good LS: 1155
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1458690 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290853.data.root:/eventsTree;1'>
# Entries:  1458690
# Good Events:  285747
# Good Tracks:  194917
# Good Entries:  157527
# Pairs:  39454
# OS:  33780
# Good OS: 2591
# LS:  5674
# Good LS: 562
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2629082 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290860.data.root:/eventsTree;1'>
# Entries:  2629082
# Good Events:  513436
# Good Tracks:  347200
# Good Entries:  281356
# Pairs:  69288
# OS:  59452
# Good OS: 4470
# LS:  9836
# Good LS: 944
# ---------------------------------------------------------------------------------------
# <Report start=2629082 stop=4862724 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290860.data.root:/eventsTree;1'>
# Entries:  4862724
# Good Events:  950676
# Good Tracks:  642796
# Good Entries:  521166
# Pairs:  127943
# OS:  109824
# Good OS: 8291
# LS:  18119
# Good LS: 1744
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=790680 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290894.data.root:/eventsTree;1'>
# Entries:  790680
# Good Events:  155095
# Good Tracks:  104827
# Good Entries:  85042
# Pairs:  20800
# OS:  17887
# Good OS: 1327
# LS:  2913
# Good LS: 302
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=271889 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290895.data.root:/eventsTree;1'>
# Entries:  271889
# Good Events:  53534
# Good Tracks:  35838
# Good Entries:  29142
# Pairs:  7035
# OS:  6052
# Good OS: 444
# LS:  983
# Good LS: 91
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1382010 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290932.data.root:/eventsTree;1'>
# Entries:  1382010
# Good Events:  271269
# Good Tracks:  188692
# Good Entries:  151522
# Pairs:  39222
# OS:  33459
# Good OS: 2581
# LS:  5763
# Good LS: 655
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=882832 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290935.data.root:/eventsTree;1'>
# Entries:  882832
# Good Events:  173354
# Good Tracks:  121134
# Good Entries:  97268
# Pairs:  25249
# OS:  21452
# Good OS: 1642
# LS:  3797
# Good LS: 418
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2341770 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290975.data.root:/eventsTree;1'>
# Entries:  2341770
# Good Events:  460836
# Good Tracks:  308320
# Good Entries:  250741
# Pairs:  60343
# OS:  51847
# Good OS: 3849
# LS:  8496
# Good LS: 895
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=351830 source='/pbs/throng/training/nantes-m2-rps-exp/data/run290980.data.root:/eventsTree;1'>
# Entries:  351830
# Good Events:  68766
# Good Tracks:  46278
# Good Entries:  37589
# Pairs:  9111
# OS:  7884
# Good OS: 552
# LS:  1227
# Good LS: 110
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2617969 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291002.data.root:/eventsTree;1'>
# Entries:  2617969
# Good Events:  514606
# Good Tracks:  347524
# Good Entries:  281405
# Pairs:  69856
# OS:  59606
# Good OS: 4550
# LS:  10250
# Good LS: 1156
# ---------------------------------------------------------------------------------------
# <Report start=2617969 stop=3300360 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291002.data.root:/eventsTree;1'>
# Entries:  3300360
# Good Events:  648438
# Good Tracks:  438084
# Good Entries:  354892
# Pairs:  87893
# OS:  74919
# Good OS: 5729
# LS:  12974
# Good LS: 1444
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2174208 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291003.data.root:/eventsTree;1'>
# Entries:  2174208
# Good Events:  426567
# Good Tracks:  288365
# Good Entries:  233440
# Pairs:  57766
# OS:  49494
# Good OS: 3691
# LS:  8272
# Good LS: 858
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2627012 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291004.data.root:/eventsTree;1'>
# Entries:  2627012
# Good Events:  515661
# Good Tracks:  348496
# Good Entries:  282516
# Pairs:  69504
# OS:  59450
# Good OS: 4431
# LS:  10054
# Good LS: 1060
# ---------------------------------------------------------------------------------------
# <Report start=2627012 stop=3324783 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291004.data.root:/eventsTree;1'>
# Entries:  3324783
# Good Events:  652283
# Good Tracks:  440676
# Good Entries:  357144
# Pairs:  87970
# OS:  75282
# Good OS: 5600
# LS:  12688
# Good LS: 1327
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1015867 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291005.data.root:/eventsTree;1'>
# Entries:  1015867
# Good Events:  198273
# Good Tracks:  133660
# Good Entries:  108435
# Pairs:  26528
# OS:  22879
# Good OS: 1689
# LS:  3649
# Good LS: 337
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2618340 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291041.data.root:/eventsTree;1'>
# Entries:  2618340
# Good Events:  510635
# Good Tracks:  346626
# Good Entries:  280320
# Pairs:  69804
# OS:  59828
# Good OS: 4383
# LS:  9976
# Good LS: 1099
# ---------------------------------------------------------------------------------------
# <Report start=2618340 stop=3859564 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291041.data.root:/eventsTree;1'>
# Entries:  3859564
# Good Events:  752328
# Good Tracks:  510841
# Good Entries:  413062
# Pairs:  102961
# OS:  88129
# Good OS: 6488
# LS:  14832
# Good LS: 1612
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2509195 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291263.data.root:/eventsTree;1'>
# Entries:  2509195
# Good Events:  490409
# Good Tracks:  365004
# Good Entries:  289982
# Pairs:  79083
# OS:  67863
# Good OS: 5019
# LS:  11220
# Good LS: 1132
# ---------------------------------------------------------------------------------------
# <Report start=2509195 stop=4982352 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291263.data.root:/eventsTree;1'>
# Entries:  4982352
# Good Events:  974640
# Good Tracks:  724803
# Good Entries:  575709
# Pairs:  157199
# OS:  135050
# Good OS: 9900
# LS:  22149
# Good LS: 2169
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1122654 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291283.data.root:/eventsTree;1'>
# Entries:  1122654
# Good Events:  220446
# Good Tracks:  163966
# Good Entries:  130147
# Pairs:  35606
# OS:  30727
# Good OS: 2285
# LS:  4879
# Good LS: 435
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2375039 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291284.data.root:/eventsTree;1'>
# Entries:  2375039
# Good Events:  464499
# Good Tracks:  344416
# Good Entries:  274069
# Pairs:  74049
# OS:  63856
# Good OS: 4534
# LS:  10193
# Good LS: 941
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=434083 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291285.data.root:/eventsTree;1'>
# Entries:  434083
# Good Events:  84969
# Good Tracks:  62997
# Good Entries:  50161
# Pairs:  13488
# OS:  11654
# Good OS: 773
# LS:  1834
# Good LS: 158
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2501775 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291360.data.root:/eventsTree;1'>
# Entries:  2501775
# Good Events:  490408
# Good Tracks:  363924
# Good Entries:  288477
# Pairs:  79654
# OS:  68237
# Good OS: 5205
# LS:  11417
# Good LS: 1231
# ---------------------------------------------------------------------------------------
# <Report start=2501775 stop=3057276 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291360.data.root:/eventsTree;1'>
# Entries:  3057276
# Good Events:  599248
# Good Tracks:  444778
# Good Entries:  352590
# Pairs:  97285
# OS:  83295
# Good OS: 6382
# LS:  13990
# Good LS: 1512
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=557691 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291361.data.root:/eventsTree;1'>
# Entries:  557691
# Good Events:  109696
# Good Tracks:  81790
# Good Entries:  64936
# Pairs:  17809
# OS:  15251
# Good OS: 1114
# LS:  2558
# Good LS: 271
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2187322 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291362.data.root:/eventsTree;1'>
# Entries:  2187322
# Good Events:  429250
# Good Tracks:  318667
# Good Entries:  253120
# Pairs:  69167
# OS:  59408
# Good OS: 4422
# LS:  9759
# Good LS: 1039
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=418755 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291373.data.root:/eventsTree;1'>
# Entries:  418755
# Good Events:  87639
# Good Tracks:  65242
# Good Entries:  52665
# Pairs:  13283
# OS:  11298
# Good OS: 782
# LS:  1985
# Good LS: 169
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1182821 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291399.data.root:/eventsTree;1'>
# Entries:  1182821
# Good Events:  231185
# Good Tracks:  171371
# Good Entries:  136213
# Pairs:  37054
# OS:  31811
# Good OS: 2311
# LS:  5243
# Good LS: 459
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1117292 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291400.data.root:/eventsTree;1'>
# Entries:  1117292
# Good Events:  220591
# Good Tracks:  163703
# Good Entries:  130068
# Pairs:  35454
# OS:  30483
# Good OS: 2291
# LS:  4971
# Good LS: 425
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1689847 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291447.data.root:/eventsTree;1'>
# Entries:  1689847
# Good Events:  333019
# Good Tracks:  239367
# Good Entries:  191318
# Pairs:  50656
# OS:  43222
# Good OS: 3248
# LS:  7434
# Good LS: 841
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1074742 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291451.data.root:/eventsTree;1'>
# Entries:  1074742
# Good Events:  212201
# Good Tracks:  151976
# Good Entries:  121646
# Pairs:  31960
# OS:  27409
# Good OS: 2011
# LS:  4551
# Good LS: 479
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2548412 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291453.data.root:/eventsTree;1'>
# Entries:  2548412
# Good Events:  500076
# Good Tracks:  358324
# Good Entries:  287038
# Pairs:  75052
# OS:  64281
# Good OS: 4785
# LS:  10771
# Good LS: 1072
# ---------------------------------------------------------------------------------------
# <Report start=2548412 stop=4257403 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291453.data.root:/eventsTree;1'>
# Entries:  4257403
# Good Events:  835030
# Good Tracks:  598733
# Good Entries:  479542
# Pairs:  125482
# OS:  107492
# Good OS: 7908
# LS:  17990
# Good LS: 1849
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2510109 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291482.data.root:/eventsTree;1'>
# Entries:  2510109
# Good Events:  492186
# Good Tracks:  364847
# Good Entries:  289845
# Pairs:  78985
# OS:  67885
# Good OS: 5039
# LS:  11100
# Good LS: 1131
# ---------------------------------------------------------------------------------------
# <Report start=2510109 stop=2707583 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291482.data.root:/eventsTree;1'>
# Entries:  2707583
# Good Events:  530803
# Good Tracks:  393527
# Good Entries:  312638
# Pairs:  85217
# OS:  73195
# Good OS: 5423
# LS:  12022
# Good LS: 1218
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=529618 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291485.data.root:/eventsTree;1'>
# Entries:  529618
# Good Events:  103722
# Good Tracks:  76958
# Good Entries:  61109
# Pairs:  16708
# OS:  14382
# Good OS: 1043
# LS:  2326
# Good LS: 219
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2093697 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291590.data.root:/eventsTree;1'>
# Entries:  2093697
# Good Events:  408906
# Good Tracks:  290632
# Good Entries:  232028
# Pairs:  61931
# OS:  52791
# Good OS: 4130
# LS:  9140
# Good LS: 1068
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1063593 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291618.data.root:/eventsTree;1'>
# Entries:  1063593
# Good Events:  207404
# Good Tracks:  146712
# Good Entries:  117311
# Pairs:  31056
# OS:  26568
# Good OS: 2081
# LS:  4488
# Good LS: 470
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=987542 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291622.data.root:/eventsTree;1'>
# Entries:  987542
# Good Events:  193041
# Good Tracks:  136860
# Good Entries:  109526
# Pairs:  28861
# OS:  24666
# Good OS: 1817
# LS:  4195
# Good LS: 445
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1742064 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291624.data.root:/eventsTree;1'>
# Entries:  1742064
# Good Events:  339583
# Good Tracks:  239181
# Good Entries:  191704
# Pairs:  50098
# OS:  42798
# Good OS: 3367
# LS:  7300
# Good LS: 718
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1366372 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291657.data.root:/eventsTree;1'>
# Entries:  1366372
# Good Events:  267806
# Good Tracks:  189765
# Good Entries:  151536
# Pairs:  40368
# OS:  34431
# Good OS: 2748
# LS:  5937
# Good LS: 694
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=620438 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291690.data.root:/eventsTree;1'>
# Entries:  620438
# Good Events:  121469
# Good Tracks:  85683
# Good Entries:  68600
# Pairs:  18053
# OS:  15282
# Good OS: 1241
# LS:  2771
# Good LS: 371
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1029098 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291692.data.root:/eventsTree;1'>
# Entries:  1029098
# Good Events:  201440
# Good Tracks:  142445
# Good Entries:  114077
# Pairs:  29952
# OS:  25510
# Good OS: 2102
# LS:  4442
# Good LS: 511
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1232789 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291694.data.root:/eventsTree;1'>
# Entries:  1232789
# Good Events:  241357
# Good Tracks:  170450
# Good Entries:  136807
# Pairs:  35468
# OS:  30263
# Good OS: 2388
# LS:  5205
# Good LS: 589
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1203911 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291698.data.root:/eventsTree;1'>
# Entries:  1203911
# Good Events:  235010
# Good Tracks:  166640
# Good Entries:  133484
# Pairs:  34958
# OS:  30018
# Good OS: 2349
# LS:  4940
# Good LS: 513
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2373951 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291706.data.root:/eventsTree;1'>
# Entries:  2373951
# Good Events:  463856
# Good Tracks:  327945
# Good Entries:  262941
# Pairs:  68475
# OS:  58746
# Good OS: 4378
# LS:  9729
# Good LS: 1011
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1954883 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291755.data.root:/eventsTree;1'>
# Entries:  1954883
# Good Events:  382021
# Good Tracks:  270749
# Good Entries:  216401
# Pairs:  57493
# OS:  48850
# Good OS: 3765
# LS:  8643
# Good LS: 1039
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=45161 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291760.data.root:/eventsTree;1'>
# Entries:  45161
# Good Events:  8929
# Good Tracks:  6405
# Good Entries:  5079
# Pairs:  1412
# OS:  1209
# Good OS: 82
# LS:  203
# Good LS: 20
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2374680 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291769.data.root:/eventsTree;1'>
# Entries:  2374680
# Good Events:  463143
# Good Tracks:  327416
# Good Entries:  262446
# Pairs:  68298
# OS:  58804
# Good OS: 4543
# LS:  9494
# Good LS: 946
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=326857 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291795.data.root:/eventsTree;1'>
# Entries:  326857
# Good Events:  64309
# Good Tracks:  45191
# Good Entries:  36173
# Pairs:  9576
# OS:  8138
# Good OS: 655
# LS:  1438
# Good LS: 155
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=564228 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291796.data.root:/eventsTree;1'>
# Entries:  564228
# Good Events:  111574
# Good Tracks:  78453
# Good Entries:  62764
# Pairs:  16519
# OS:  14183
# Good OS: 1094
# LS:  2336
# Good LS: 259
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=746907 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291803.data.root:/eventsTree;1'>
# Entries:  746907
# Good Events:  146795
# Good Tracks:  103602
# Good Entries:  82810
# Pairs:  21937
# OS:  18771
# Good OS: 1436
# LS:  3166
# Good LS: 322
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2338087 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291943.data.root:/eventsTree;1'>
# Entries:  2338087
# Good Events:  459742
# Good Tracks:  323601
# Good Entries:  259072
# Pairs:  68000
# OS:  58024
# Good OS: 4463
# LS:  9976
# Good LS: 1078
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1638174 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291944.data.root:/eventsTree;1'>
# Entries:  1638174
# Good Events:  321278
# Good Tracks:  226536
# Good Entries:  181438
# Pairs:  47596
# OS:  40773
# Good OS: 3183
# LS:  6823
# Good LS: 746
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2568000 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291948.data.root:/eventsTree;1'>
# Entries:  2568000
# Good Events:  503543
# Good Tracks:  354309
# Good Entries:  284131
# Pairs:  73914
# OS:  63482
# Good OS: 4809
# LS:  10432
# Good LS: 1059
# ---------------------------------------------------------------------------------------
# <Report start=2568000 stop=2788435 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291948.data.root:/eventsTree;1'>
# Entries:  2788435
# Good Events:  546837
# Good Tracks:  384783
# Good Entries:  308525
# Pairs:  80321
# OS:  68971
# Good OS: 5259
# LS:  11350
# Good LS: 1140
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=53087 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291953.data.root:/eventsTree;1'>
# Entries:  53087
# Good Events:  10361
# Good Tracks:  7194
# Good Entries:  5800
# Pairs:  1451
# OS:  1260
# Good OS: 99
# LS:  191
# Good LS: 18
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2183239 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291976.data.root:/eventsTree;1'>
# Entries:  2183239
# Good Events:  429399
# Good Tracks:  297958
# Good Entries:  238970
# Pairs:  62218
# OS:  53135
# Good OS: 4327
# LS:  9083
# Good LS: 1090
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1698024 source='/pbs/throng/training/nantes-m2-rps-exp/data/run291982.data.root:/eventsTree;1'>
# Entries:  1698024
# Good Events:  332595
# Good Tracks:  233986
# Good Entries:  187450
# Pairs:  48993
# OS:  42017
# Good OS: 3253
# LS:  6976
# Good LS: 755
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1657730 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292012.data.root:/eventsTree;1'>
# Entries:  1657730
# Good Events:  325592
# Good Tracks:  228378
# Good Entries:  182880
# Pairs:  48021
# OS:  40849
# Good OS: 3285
# LS:  7172
# Good LS: 865
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2558717 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292040.data.root:/eventsTree;1'>
# Entries:  2558717
# Good Events:  504450
# Good Tracks:  353331
# Good Entries:  282567
# Pairs:  74779
# OS:  63560
# Good OS: 5076
# LS:  11219
# Good LS: 1313
# ---------------------------------------------------------------------------------------
# <Report start=2558717 stop=2695419 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292040.data.root:/eventsTree;1'>
# Entries:  2695419
# Good Events:  531298
# Good Tracks:  372280
# Good Entries:  297659
# Pairs:  78866
# OS:  67008
# Good OS: 5365
# LS:  11858
# Good LS: 1397
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1943919 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292060.data.root:/eventsTree;1'>
# Entries:  1943919
# Good Events:  383236
# Good Tracks:  269159
# Good Entries:  215399
# Pairs:  56839
# OS:  48189
# Good OS: 3769
# LS:  8650
# Good LS: 1018
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1329679 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292061.data.root:/eventsTree;1'>
# Entries:  1329679
# Good Events:  261130
# Good Tracks:  182902
# Good Entries:  146482
# Pairs:  38459
# OS:  32839
# Good OS: 2562
# LS:  5620
# Good LS: 617
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2562786 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292062.data.root:/eventsTree;1'>
# Entries:  2562786
# Good Events:  503208
# Good Tracks:  353348
# Good Entries:  283392
# Pairs:  73666
# OS:  63089
# Good OS: 4754
# LS:  10577
# Good LS: 1122
# ---------------------------------------------------------------------------------------
# <Report start=2562786 stop=3991724 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292062.data.root:/eventsTree;1'>
# Entries:  3991724
# Good Events:  784319
# Good Tracks:  550133
# Good Entries:  441390
# Pairs:  114454
# OS:  97961
# Good OS: 7512
# LS:  16493
# Good LS: 1736
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2364477 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292075.data.root:/eventsTree;1'>
# Entries:  2364477
# Good Events:  463515
# Good Tracks:  325311
# Good Entries:  260856
# Pairs:  67855
# OS:  57993
# Good OS: 4394
# LS:  9862
# Good LS: 982
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=994465 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292077.data.root:/eventsTree;1'>
# Entries:  994465
# Good Events:  194839
# Good Tracks:  136633
# Good Entries:  109736
# Pairs:  28397
# OS:  24328
# Good OS: 1865
# LS:  4069
# Good LS: 470
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1519597 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292080.data.root:/eventsTree;1'>
# Entries:  1519597
# Good Events:  298648
# Good Tracks:  210192
# Good Entries:  168600
# Pairs:  43837
# OS:  37586
# Good OS: 2855
# LS:  6251
# Good LS: 632
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1345826 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292106.data.root:/eventsTree;1'>
# Entries:  1345826
# Good Events:  265281
# Good Tracks:  186495
# Good Entries:  149253
# Pairs:  39339
# OS:  33522
# Good OS: 2671
# LS:  5817
# Good LS: 746
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1158616 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292108.data.root:/eventsTree;1'>
# Entries:  1158616
# Good Events:  227347
# Good Tracks:  159933
# Good Entries:  128259
# Pairs:  33342
# OS:  28620
# Good OS: 2205
# LS:  4722
# Good LS: 462
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=987987 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292109.data.root:/eventsTree;1'>
# Entries:  987987
# Good Events:  193549
# Good Tracks:  136475
# Good Entries:  109231
# Pairs:  28806
# OS:  24576
# Good OS: 1850
# LS:  4230
# Good LS: 436
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2566825 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292115.data.root:/eventsTree;1'>
# Entries:  2566825
# Good Events:  501972
# Good Tracks:  353911
# Good Entries:  283842
# Pairs:  73830
# OS:  63422
# Good OS: 5014
# LS:  10408
# Good LS: 982
# ---------------------------------------------------------------------------------------
# <Report start=2566825 stop=3205613 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292115.data.root:/eventsTree;1'>
# Entries:  3205613
# Good Events:  627202
# Good Tracks:  442168
# Good Entries:  354654
# Pairs:  92211
# OS:  79135
# Good OS: 6184
# LS:  13076
# Good LS: 1234
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=216102 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292140.data.root:/eventsTree;1'>
# Entries:  216102
# Good Events:  42226
# Good Tracks:  29640
# Good Entries:  23652
# Pairs:  6378
# OS:  5365
# Good OS: 401
# LS:  1013
# Good LS: 125
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2554955 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292160.data.root:/eventsTree;1'>
# Entries:  2554955
# Good Events:  502498
# Good Tracks:  353189
# Good Entries:  282878
# Pairs:  74163
# OS:  63215
# Good OS: 5050
# LS:  10948
# Good LS: 1269
# ---------------------------------------------------------------------------------------
# <Report start=2554955 stop=4185141 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292160.data.root:/eventsTree;1'>
# Entries:  4185141
# Good Events:  823109
# Good Tracks:  578507
# Good Entries:  463129
# Pairs:  121785
# OS:  103704
# Good OS: 8257
# LS:  18081
# Good LS: 2074
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=265415 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292162.data.root:/eventsTree;1'>
# Entries:  265415
# Good Events:  52837
# Good Tracks:  37344
# Good Entries:  29875
# Pairs:  7902
# OS:  6721
# Good OS: 492
# LS:  1181
# Good LS: 131
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1428672 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292163.data.root:/eventsTree;1'>
# Entries:  1428672
# Good Events:  280036
# Good Tracks:  197321
# Good Entries:  158008
# Pairs:  41446
# OS:  35446
# Good OS: 2749
# LS:  6000
# Good LS: 654
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=266213 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292164.data.root:/eventsTree;1'>
# Entries:  266213
# Good Events:  52512
# Good Tracks:  36635
# Good Entries:  29308
# Pairs:  7735
# OS:  6579
# Good OS: 495
# LS:  1156
# Good LS: 119
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1091472 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292166.data.root:/eventsTree;1'>
# Entries:  1091472
# Good Events:  214421
# Good Tracks:  151347
# Good Entries:  121079
# Pairs:  31936
# OS:  27234
# Good OS: 2007
# LS:  4702
# Good LS: 481
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2027609 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292168.data.root:/eventsTree;1'>
# Entries:  2027609
# Good Events:  397537
# Good Tracks:  279590
# Good Entries:  224431
# Pairs:  58267
# OS:  49899
# Good OS: 3854
# LS:  8368
# Good LS: 879
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=253590 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292192.data.root:/eventsTree;1'>
# Entries:  253590
# Good Events:  50200
# Good Tracks:  34970
# Good Entries:  28040
# Pairs:  7310
# OS:  6228
# Good OS: 484
# LS:  1082
# Good LS: 129
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=908405 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292242.data.root:/eventsTree;1'>
# Entries:  908405
# Good Events:  179581
# Good Tracks:  124165
# Good Entries:  99692
# Pairs:  25766
# OS:  22101
# Good OS: 1781
# LS:  3665
# Good LS: 363
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=902814 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292265.data.root:/eventsTree;1'>
# Entries:  902814
# Good Events:  178586
# Good Tracks:  123984
# Good Entries:  99224
# Pairs:  26193
# OS:  22227
# Good OS: 1853
# LS:  3966
# Good LS: 500
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=228162 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292269.data.root:/eventsTree;1'>
# Entries:  228162
# Good Events:  45167
# Good Tracks:  31332
# Good Entries:  25068
# Pairs:  6607
# OS:  5600
# Good OS: 444
# LS:  1007
# Good LS: 129
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1189721 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292270.data.root:/eventsTree;1'>
# Entries:  1189721
# Good Events:  234929
# Good Tracks:  163450
# Good Entries:  130779
# Pairs:  34572
# OS:  29381
# Good OS: 2378
# LS:  5191
# Good LS: 600
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=2564684 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292273.data.root:/eventsTree;1'>
# Entries:  2564684
# Good Events:  506129
# Good Tracks:  351999
# Good Entries:  282127
# Pairs:  73753
# OS:  63038
# Good OS: 4963
# LS:  10715
# Good LS: 1211
# ---------------------------------------------------------------------------------------
# <Report start=2564684 stop=3252177 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292273.data.root:/eventsTree;1'>
# Entries:  3252177
# Good Events:  641776
# Good Tracks:  446353
# Good Entries:  357822
# Pairs:  93436
# OS:  79842
# Good OS: 6256
# LS:  13594
# Good LS: 1501
# ---------------------------------------------------------------------------------------
# <Report start=0 stop=1353844 source='/pbs/throng/training/nantes-m2-rps-exp/data/run292274.data.root:/eventsTree;1'>
# Entries:  1353844
# Good Events:  267487
# Good Tracks:  186145
# Good Entries:  149181
# Pairs:  38978
# OS:  33241
# Good OS: 2629
# LS:  5737
# Good LS: 637
# ---------------------------------------------------------------------------------------
# Entries:  180055828
# Good Events:  35243671
# Good Tracks:  24781220
# Good Entries:  19878485
# Pairs:  5167809
# OS:  4424641
# Good OS:  339119
# LS:  743168
# Good LS:  78654
# CPU times: user 9min 47s, sys: 9.09 s, total: 9min 56s
# Wall time: 13min 50s

# %%
hMag.plot(color = "blue", label = "data")
plt.yscale('log')
plt.ylabel("# of tracks")
plt.grid(True)
plt.legend()

# %%
hPhi.plot(color = "blue", label = "data")
plt.ylabel("# of tracks")
plt.grid(True)
plt.legend()

# %%
hPt.plot(color = "blue", label = "data")
plt.yscale('log')
plt.ylabel("# of tracks")
plt.grid(True)
plt.legend()

# %%
hEta.plot(color = "blue", label = "data")
plt.ylabel("# of tracks")
plt.grid(True)
plt.legend()

# %%
hY_OS.plot(color = "blue", label = "data")
plt.ylabel("# of tracks")
plt.grid(True)
plt.legend()

# %%
hMass.plot(color = "blue", label = "data")
plt.yscale('log')
plt.ylabel("# of tracks")
plt.grid(True)
plt.legend()

# %%
hMass_OS.plot(color = "blue", label = "data")
plt.yscale('log')
plt.ylabel("# of tracks")
plt.grid(True)
plt.legend()

# %%
hMass_LS.plot(color = "blue", label = "data")
plt.yscale('log')
plt.ylabel("# of tracks")
plt.grid(True)
plt.legend()

# %%
print(hMass_OS.axes[0].centers.tolist())
print(hMass_OS.view().tolist())
print(hMass_LS.view().tolist())
# Out:
# [1.5099999999999998, 1.53, 1.55, 1.57, 1.59, 1.6099999999999999, 1.6300000000000001, 1.65, 1.67, 1.69, 1.71, 1.73, 1.75, 1.77, 1.79, 1.81, 1.83, 1.85, 1.87, 1.89, 1.9100000000000001, 1.93, 1.95, 1.97, 1.9900000000000002, 2.0100000000000002, 2.03, 2.05, 2.0700000000000003, 2.09, 2.1100000000000003, 2.13, 2.1500000000000004, 2.17, 2.19, 2.21, 2.23, 2.25, 2.27, 2.29, 2.3099999999999996, 2.33, 2.3499999999999996, 2.37, 2.39, 2.41, 2.43, 2.45, 2.4699999999999998, 2.49, 2.5100000000000002, 2.5300000000000002, 2.55, 2.57, 2.59, 2.61, 2.63, 2.65, 2.67, 2.69, 2.71, 2.73, 2.75, 2.7700000000000005, 2.79, 2.81, 2.83, 2.85, 2.87, 2.89, 2.91, 2.9299999999999997, 2.95, 2.97, 2.99, 3.01, 3.0300000000000002, 3.0500000000000003, 3.07, 3.09, 3.1100000000000003, 3.13, 3.1500000000000004, 3.17, 3.1900000000000004, 3.21, 3.2300000000000004, 3.25, 3.27, 3.29, 3.3099999999999996, 3.3300000000000005, 3.3499999999999996, 3.37, 3.39, 3.41, 3.43, 3.4499999999999997, 3.4699999999999998, 3.49, 3.51, 3.5300000000000002, 3.5500000000000003, 3.5700000000000003, 3.59, 3.61, 3.63, 3.6500000000000004, 3.67, 3.6899999999999995, 3.7100000000000004, 3.7299999999999995, 3.75, 3.77, 3.79, 3.8100000000000005, 3.8299999999999996, 3.8499999999999996, 3.87, 3.8899999999999997, 3.91, 3.93, 3.95, 3.9699999999999998, 3.9899999999999998, 4.01, 4.03, 4.05, 4.07, 4.09, 4.109999999999999, 4.13, 4.15, 4.17, 4.19, 4.21, 4.23, 4.25, 4.2700000000000005, 4.29, 4.31, 4.33, 4.35, 4.37, 4.390000000000001, 4.409999999999999, 4.43, 4.45, 4.47, 4.49, 4.51, 4.53, 4.550000000000001, 4.569999999999999, 4.59, 4.61, 4.63, 4.65, 4.67, 4.6899999999999995, 4.71, 4.7299999999999995, 4.75, 4.7700000000000005, 4.789999999999999, 4.8100000000000005, 4.83, 4.85, 4.87, 4.89, 4.91, 4.930000000000001, 4.95, 4.97, 4.99]
# [2025.0, 1955.0, 2005.0, 2056.0, 1905.0, 2032.0, 2022.0, 1884.0, 1944.0, 1964.0, 1888.0, 1989.0, 1990.0, 1844.0, 1971.0, 1885.0, 1836.0, 1840.0, 1790.0, 1818.0, 1812.0, 1742.0, 1768.0, 1720.0, 1672.0, 1677.0, 1656.0, 1631.0, 1565.0, 1530.0, 1591.0, 1544.0, 1480.0, 1536.0, 1446.0, 1415.0, 1379.0, 1392.0, 1410.0, 1412.0, 1312.0, 1259.0, 1251.0, 1280.0, 1235.0, 1131.0, 1154.0, 1135.0, 1196.0, 1119.0, 1098.0, 1057.0, 1058.0, 1061.0, 1076.0, 1024.0, 965.0, 1003.0, 979.0, 927.0, 960.0, 920.0, 941.0, 871.0, 910.0, 878.0, 884.0, 886.0, 919.0, 1042.0, 1070.0, 1112.0, 1214.0, 1325.0, 1446.0, 1751.0, 2055.0, 2332.0, 2683.0, 2953.0, 2864.0, 2789.0, 2545.0, 1956.0, 1534.0, 1194.0, 846.0, 699.0, 578.0, 516.0, 470.0, 441.0, 438.0, 431.0, 384.0, 428.0, 397.0, 393.0, 365.0, 375.0, 364.0, 355.0, 353.0, 357.0, 337.0, 339.0, 355.0, 372.0, 355.0, 349.0, 347.0, 338.0, 289.0, 300.0, 312.0, 266.0, 276.0, 250.0, 244.0, 237.0, 263.0, 219.0, 227.0, 199.0, 201.0, 207.0, 212.0, 230.0, 199.0, 197.0, 223.0, 211.0, 188.0, 166.0, 204.0, 188.0, 179.0, 186.0, 167.0, 169.0, 197.0, 174.0, 159.0, 174.0, 173.0, 153.0, 162.0, 151.0, 159.0, 132.0, 158.0, 150.0, 156.0, 127.0, 125.0, 141.0, 145.0, 136.0, 137.0, 127.0, 119.0, 116.0, 124.0, 109.0, 137.0, 111.0, 118.0, 121.0, 107.0, 111.0, 96.0, 98.0, 94.0, 102.0, 108.0]
# [451.0, 474.0, 484.0, 455.0, 449.0, 455.0, 453.0, 465.0, 461.0, 425.0, 416.0, 436.0, 409.0, 427.0, 423.0, 406.0, 397.0, 419.0, 399.0, 370.0, 366.0, 390.0, 336.0, 343.0, 348.0, 349.0, 375.0, 339.0, 335.0, 363.0, 358.0, 293.0, 311.0, 297.0, 303.0, 281.0, 312.0, 282.0, 263.0, 294.0, 285.0, 290.0, 272.0, 274.0, 282.0, 264.0, 239.0, 227.0, 252.0, 259.0, 249.0, 243.0, 226.0, 249.0, 188.0, 216.0, 231.0, 238.0, 243.0, 248.0, 204.0, 233.0, 242.0, 191.0, 205.0, 208.0, 215.0, 198.0, 188.0, 179.0, 189.0, 180.0, 199.0, 168.0, 173.0, 171.0, 159.0, 188.0, 198.0, 147.0, 166.0, 158.0, 143.0, 178.0, 150.0, 157.0, 141.0, 137.0, 154.0, 142.0, 164.0, 158.0, 151.0, 167.0, 140.0, 142.0, 136.0, 143.0, 149.0, 131.0, 107.0, 143.0, 135.0, 114.0, 128.0, 138.0, 128.0, 132.0, 108.0, 113.0, 113.0, 114.0, 114.0, 119.0, 85.0, 102.0, 107.0, 121.0, 112.0, 95.0, 109.0, 100.0, 89.0, 102.0, 114.0, 97.0, 107.0, 107.0, 94.0, 83.0, 101.0, 81.0, 110.0, 98.0, 86.0, 81.0, 72.0, 80.0, 79.0, 92.0, 88.0, 95.0, 85.0, 77.0, 88.0, 75.0, 85.0, 78.0, 85.0, 69.0, 86.0, 81.0, 73.0, 79.0, 75.0, 72.0, 62.0, 62.0, 71.0, 82.0, 91.0, 78.0, 70.0, 64.0, 61.0, 80.0, 60.0, 64.0, 56.0, 64.0, 70.0, 69.0, 66.0, 57.0, 52.0]

# %%
print(dir(vector.backends.awkward.MomentumArray4D))
# Out:
# ['E', 'E2', 'Et', 'Et2', 'GenericClass', 'M', 'M2', 'Mask', 'Mt', 'Mt2', 'ProjectionClass2D', 'ProjectionClass3D', 'ProjectionClass4D', '__abs__', '__abstractmethods__', '__add__', '__and__', '__annotations__', '__array__', '__array_function__', '__array_ufunc__', '__arrow_array__', '__bool__', '__bytes__', '__cast_cpp__', '__class__', '__class_getitem__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__ilshift__', '__imatmul__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', '__xor__', '_abc_impl', '_histogram_module_', '_ipython_key_completions_', '_repr', '_repr_mimebundle_', '_wrap_result', 'add', 'allclose', 'azimuthal', 'behavior', 'beta', 'boost', 'boostCM_of', 'boostCM_of_beta3', 'boostCM_of_p4', 'boostX', 'boostY', 'boostZ', 'boost_beta3', 'boost_p4', 'costheta', 'cottheta', 'cpp_type', 'cross', 'deltaR', 'deltaR2', 'deltaRapidityPhi', 'deltaRapidityPhi2', 'deltaangle', 'deltaeta', 'deltaphi', 'dot', 'e', 'e2', 'energy', 'energy2', 'equal', 'et', 'et2', 'eta', 'fields', 'gamma', 'is_antiparallel', 'is_lightlike', 'is_parallel', 'is_perpendicular', 'is_spacelike', 'is_timelike', 'is_tuple', 'isclose', 'layout', 'lib', 'longitudinal', 'm', 'm2', 'mag', 'mag2', 'mask', 'mass', 'mass2', 'mt', 'mt2', 'nbytes', 'ndim', 'neg2D', 'neg3D', 'neg4D', 'not_equal', 'numba_type', 'p', 'p2', 'phi', 'pseudorapidity', 'pt', 'pt2', 'px', 'py', 'pz', 'rapidity', 'rho', 'rho2', 'rotateX', 'rotateY', 'rotateZ', 'rotate_axis', 'rotate_euler', 'rotate_nautical', 'rotate_quaternion', 'scale', 'scale2D', 'scale3D', 'scale4D', 'show', 'subtract', 't', 't2', 'tau', 'tau2', 'temporal', 'theta', 'to_Vector2D', 'to_Vector3D', 'to_Vector4D', 'to_beta3', 'to_list', 'to_numpy', 'to_rhophi', 'to_rhophieta', 'to_rhophietat', 'to_rhophietatau', 'to_rhophitheta', 'to_rhophithetat', 'to_rhophithetatau', 'to_rhophiz', 'to_rhophizt', 'to_rhophiztau', 'to_xy', 'to_xyeta', 'to_xyetat', 'to_xyetatau', 'to_xytheta', 'to_xythetat', 'to_xythetatau', 'to_xyz', 'to_xyzt', 'to_xyztau', 'tolist', 'transform2D', 'transform3D', 'transform4D', 'transverse_energy', 'transverse_energy2', 'transverse_mass', 'transverse_mass2', 'type', 'typestr', 'unit', 'x', 'y', 'z']
